# %%
import numpy as np
import matplotlib.pyplot as plt

import symmetric_methods as sm

# %%
# MLP structure

L = 2

dim = np.zeros((L+1,))

dim[0] = 9
dim[1] = 7
dim[2] = 5
#dim[3] = 7
#dim[4] = 9
#dim[5] = 8
#dim[6] = 9
#dim[7] = 10
#dim[8] = 11
#dim[9] = 12

dim= dim.astype(int)

# %%
# draw random parameters, test matrix inverse 

phi = np.random.normal(0,1,(L-2,))
ttphi = np.random.normal(0,1,(L-1,))
tPhi1 = np.random.normal(0,1,(dim[0],1))
tPhiL = np.random.normal(0,1,(dim[L],1))
PHI1 = np.random.normal(0,1,(dim[0],dim[0]))
PHI1 = PHI1 + PHI1.T
PHIL = np.random.normal(0,1,(dim[L],dim[L]))
PHIL = PHIL + PHIL.T
ttPHIL = np.random.normal(0,1,(dim[L],dim[L]))
ttPHIL = ttPHIL + ttPHIL.T
PSI1 = []
if L==2:
    PSI1 = np.random.normal(0,1,(dim[0],dim[2]))
    

covg = sm.par2cov(L,dim,phi,ttphi,tPhi1,tPhiL,PHI1,PSI1,PHIL,ttPHIL)
icovg = np.linalg.inv(covg)

phi_inv,ttphi_inv,tPhi1_inv,tPhiL_inv,PHI1_inv,PSI1_inv,PHIL_inv,ttPHIL_inv = sm.cov2par(L,dim,icovg)

phi_invest,ttphi_invest,tPhi1_invest,tPhiL_invest,PHI1_invest,PSI1_invest,PHIL_invest,ttPHIL_invest = sm.inverse(L,dim,phi,ttphi,tPhi1,tPhiL,PHI1,PSI1,PHIL,ttPHIL)

icovgest = sm.par2cov(L,dim,phi_invest,ttphi_invest,tPhi1_invest,tPhiL_invest,PHI1_invest,PSI1_invest,PHIL_invest,ttPHIL_invest)

# %%
plt.plot(icovg,icovgest,linestyle='none',marker='.')
plt.plot([np.min(icovg), np.max(icovg)],[np.min(icovg), np.max(icovg)])
plt.show()


print(phi_inv)
print('\n')
print(phi_invest)
print('\n')
print(ttphi_inv)
print('\n')
print(ttphi_invest)
print('\n')
print(tPhi1_inv)
print('\n')
print(tPhi1_invest)
print('\n')
print(tPhiL_inv)
print('\n')
print(tPhiL_invest)
print('\n')
print(PHI1_inv)
print('\n')
print(PHI1_invest)
print('\n')
print(PSI1_inv)
print('\n')
print(PSI1_invest)
print('\n')
print(PHIL_inv)
print('\n')
print(PHIL_invest)
print('\n')
print(ttPHIL_inv)
print('\n')
print(ttPHIL_invest)
# Out:
# []
#
#
# []
#
#
# [0.70942365]
#
#
# [0.70942365]
#
#
# [[-0.24045073]
#  [ 0.25334289]
#  [ 0.25918768]
#  [ 0.32905808]
#  [ 0.34035614]
#  [-0.02783537]
#  [-0.67666692]
#  [-0.10542096]
#  [-1.40844166]]
#
#
# [[-0.24045073]
#  [ 0.25334289]
#  [ 0.25918768]
#  [ 0.32905808]
#  [ 0.34035614]
#  [-0.02783537]
#  [-0.67666692]
#  [-0.10542096]
#  [-1.40844166]]
#
#
# [[-0.12608478]
#  [ 1.1814736 ]
#  [ 0.36849619]
#  [-0.65430224]
#  [-0.26620131]]
#
#
# [[-0.12608478]
#  [ 1.1814736 ]
#  [ 0.36849619]
#  [-0.65430224]
#  [-0.26620131]]
#
#
# [[ 1.33223837e-02 -2.82888701e-02 -2.06948524e-02  1.07193725e-01
#   -1.25090936e-01 -1.77689902e-01  1.96486081e-01 -4.92623952e-02
#    5.05216341e-01]
#  [-2.82888701e-02 -5.55898392e-02  1.24018059e-01 -1.49993240e-01
#    1.72216518e-01 -1.21354744e-01 -6.40351339e-02 -5.43750240e-03
#   -1.82056409e-01]
#  [-2.06948524e-02  1.24018059e-01  6.08116829e-01  9.77724958e-02
# ...
