# %%
import numpy as np
import matplotlib.pyplot as plt

import symmetric_methods as sm

# %%
# MLP structure

L = 2

dim = np.zeros((L+1,))

dim[0] = 9
dim[1] = 7
dim[2] = 5
#dim[3] = 7
#dim[4] = 9
#dim[5] = 8
#dim[6] = 9
#dim[7] = 10
#dim[8] = 11
#dim[9] = 12

dim= dim.astype(int)

# %%
# draw random parameters, test matrix inverse 

phi = np.random.normal(0,1,(L-2,))
PHI1 = np.random.normal(0,1,(dim[0],dim[0]))
PHI1 = PHI1 + PHI1.T
PHIL = np.random.normal(0,1,(dim[L],dim[L]))
PHIL = PHIL + PHIL.T
PSI1 = []
if L==2:
    PSI1 = np.random.normal(0,1,(dim[0],dim[2]))

covg = sm.par2cov(L,dim,phi,PHI1,PSI1,PHIL)
icovg = np.linalg.inv(covg)

phi_inv,PHI1_inv,PSI1_inv,PHIL_inv = sm.cov2par(L,dim,icovg)

phi_invest,PHI1_invest,PSI1_invest,PHIL_invest = sm.inverse(L,dim,phi,PHI1,PSI1,PHIL)

icovgest = sm.par2cov(L,dim,phi_invest,PHI1_invest,PSI1_invest,PHIL_invest)

# %%
plt.plot(icovg,icovgest,linestyle='none',marker='.')
plt.plot([np.min(icovg), np.max(icovg)],[np.min(icovg), np.max(icovg)])
plt.show()


print(phi_inv)
print('\n')
print(phi_invest)
print('\n')
print(PHI1_inv)
print('\n')
print(PHI1_invest)
print('\n')
print(PSI1_inv)
print('\n')
print(PSI1_invest)
print('\n')
print(PHIL_inv)
print('\n')
print(PHIL_invest)
# Out:
# []
#
#
# []
#
#
# [[-0.90086886  0.19461013 -0.28612759  0.12874539  0.10678124 -0.84934163
#   -0.8425855   0.97083973  0.205166  ]
#  [ 0.19461013 -0.20074883 -0.11571158  0.06300332 -0.00466461  0.3425584
#    0.29395526 -0.30056719 -0.08362927]
#  [-0.28612759 -0.11571158  0.52679886 -0.09428416  0.22425784 -0.39488656
#   -0.05360215 -0.01050001  0.370191  ]
#  [ 0.12874539  0.06300332 -0.09428416 -0.16664015 -0.1815847   0.48527659
#    0.17370676  0.0166472  -0.3554183 ]
#  [ 0.10678124 -0.00466461  0.22425784 -0.1815847  -0.19868736  0.40024425
#    0.35954344 -0.27769395 -0.08419486]
#  [-0.84934163  0.3425584  -0.39488656  0.48527659  0.40024425 -1.46226179
#   -1.18174995  1.03068598  0.20461598]
#  [-0.8425855   0.29395526 -0.05360215  0.17370676  0.35954344 -1.18174995
#   -1.32866485  1.21164104  0.26177551]
#  [ 0.97083973 -0.30056719 -0.01050001  0.0166472  -0.27769395  1.03068598
#    1.21164104 -0.9260384  -0.38200249]
#  [ 0.205166   -0.08362927  0.370191   -0.3554183  -0.08419486  0.20461598
#    0.26177551 -0.38200249 -0.0506381 ]]
#
#
# [[-0.90086886  0.19461013 -0.28612759  0.12874539  0.10678124 -0.84934163
#   -0.8425855   0.97083973  0.205166  ]
#  [ 0.19461013 -0.20074883 -0.11571158  0.06300332 -0.00466461  0.3425584
#    0.29395526 -0.30056719 -0.08362927]
